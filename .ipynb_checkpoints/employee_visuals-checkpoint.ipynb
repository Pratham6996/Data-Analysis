# %%
import pandas as pd

# read the Excel file
df = pd.read_excel('final_employee_dataset.xlsx')

# %%
df.describe()
# Out:
#               S.No          Age
# count  1029.000000  1029.000000
# mean    523.532556    31.883382
# std     303.439287     7.244615
# min       1.000000    18.000000
# 25%     259.000000    27.000000
# 50%     524.000000    31.000000
# 75%     786.000000    36.000000
# max    1048.000000    60.000000

# %%
import seaborn as sns  # Importing the Seaborn library for data visualization

import matplotlib.pyplot as plt  # Importing Matplotlib for plotting

sns.countplot(x='treatment', data=df)  
# Creating a count plot to show the number of employees who need treatment vs. those who don't

plt.title('Count of Employees Needing Treatment vs Not Needing Treatment')  
# Setting the title of the plot

plt.xlabel('Treatment')  
# Labeling the x-axis as "Treatment" (Yes/No)

plt.ylabel('Count')  
# Labeling the y-axis as "Count" (Number of employees)

plt.show()  
# Displaying the plot

# %% [markdown]
# Out of 1029 employees, 496 (≈48.2%) have indicated that they needed treatment, while 533 (≈51.8%) did not.
# The nearly equal distribution suggests that mental health concerns are significant in the workplace.

# %%
plt.figure(figsize=(10, 6))
# Creates a figure with a size of 10 inches wide and 6 inches tall.

sns.countplot(data=df, x='leave', hue='mental_health_consequence', palette='Set2')
# Creates a count plot to show the distribution of 'leave' categories, colored by 'mental_health_consequence'.

plt.title("Count Plot of 'leave' vs 'mental_health_consequence'")
# Sets the title of the plot.

plt.xlabel('Leave')
# Labels the x-axis as 'Leave'.

plt.ylabel('Count')
# Labels the y-axis as 'Count'.

plt.legend(title='Mental Health Consequence')
# Adds a legend with the title 'Mental Health Consequence'.

plt.xticks(rotation=45)
# Rotates the x-axis labels by 45 degrees for better readability.

plt.show()
# Displays the plot.

# %% [markdown]
#  **1️⃣ Uncertainty About Leave Increases Mental Health Concerns**
#
# + The "Don't know" category has the highest count, especially for "Maybe" and "Yes" responses in mental health consequences.
#
# + This suggests that when employees are unsure about leave policies, they are more likely to fear negative consequences for discussing mental health issues.
#
#  **2️⃣ Easier Leave Policies Reduce Mental Health Stigma**
#
# + The "Very easy" leave category has the highest count in the "No" response for mental health consequences.
#
# + This implies that in workplaces where taking mental health leave is easy, employees feel safer discussing mental health without fearing negative consequences.
#
#  **3️⃣ Strict Leave Policies Are Linked to Increased Fear of Consequences**
#
# + The "Very difficult" and "Somewhat difficult" leave categories show higher proportions of "Yes" responses.
#
# + This suggests that when it’s difficult to take leave, employees are more likely to believe that discussing mental health issues could lead to negative consequences.

# %%
# Convert 'Age' column to numeric before plotting
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')  
# Ensures that the 'Age' column contains only numeric values.
# Non-numeric values (if any) will be converted to NaN (missing values).

plt.figure(figsize=(8, 5))  
# Creates a figure with a specified size (8 inches wide, 5 inches tall).

sns.histplot(df['Age'], bins=15, kde=True, color="skyblue")  
# Creates a histogram to show the distribution of ages.
# 'bins=15' divides the age range into 15 intervals.
# 'kde=True' adds a smooth density curve to show trends.
# 'color="skyblue"' sets the color of the bars.

plt.xlim(18, 60)  
# Sets the x-axis limits to show ages between 18 and 60.

plt.xticks(range(18, 61, 5))  
# Sets the x-axis tick marks at intervals of 5 years (18, 23, 28, etc.).

plt.title("Age Distribution of Employees")  
# Sets the title of the plot.

plt.xlabel("Age")  
# Labels the x-axis as "Age".

plt.ylabel("Count")  
# Labels the y-axis as "Count" (Number of employees in each age group).

plt.show()  
# Displays the plot.

# %% [markdown]
# The age distribution is approximately normal, meaning most employees fall within a balanced age range.
#
# There are two peaks in the distribution:
# Ages 23-28: Likely representing younger employees, possibly early-career professionals.
# Ages 33-38: Representing mid-career professionals with more experience.
#
# The distribution suggests that the company's workforce consists mostly of employees in their 20s and 30s, with fewer employees in older age groups.
#
# This insight can help target wellness programs based on different career stages—younger employees might need stress management, while mid-career employees might face work-life balance challenges.

# %%
plt.figure(figsize=(8, 5))  
# Creates a figure with a size of 8 inches wide and 5 inches tall.

sns.histplot(df, x="Age", hue="treatment", bins=10, kde=True, multiple="stack",  
             palette={"Yes": "red", "No": "green"}, hue_order=["Yes", "No"])  
# Creates a histogram to show the age distribution of employees.
# 'x="Age"' specifies that the x-axis represents age.
# 'hue="treatment"' groups data by treatment requirement (Yes/No).
# 'bins=10' divides the age range into 10 intervals.
# 'kde=True' adds a smooth density curve.
# 'multiple="stack"' stacks bars instead of overlapping them.
# 'palette={"Yes": "red", "No": "green"}' assigns colors to treatment categories.
# 'hue_order=["Yes", "No"]' ensures that "Yes" (red) is plotted before "No" (green).

plt.title("Age Distribution by Treatment Requirement")  
# Sets the title of the plot.

plt.xlabel("Age")  
# Labels the x-axis as "Age".

plt.ylabel("Count")  
# Labels the y-axis as "Count" (number of employees in each age group).

plt.xticks(range(18, 61, 5))  
# Sets x-axis ticks at 5-year intervals from 18 to 60.

handles, labels = plt.gca().get_legend_handles_labels()  
# Retrieves legend handles (color boxes) and labels from the current plot.

if handles:  
    plt.legend(handles, ["Needs Treatment", "Does Not Need Treatment"], title="Treatment")  
    # Adds a legend if there are valid handles (color groups).
    # Custom labels: "Needs Treatment" (for Yes) and "Does Not Need Treatment" (for No).
    # Title of the legend is "Treatment".

plt.show()  
# Displays the plot.

# %% [markdown]
# **1️⃣ Age Groups Most in Need of Treatment:**
#
# The highest number of employees needing treatment falls between 23 to 28 years and 33 to 38 years, as seen from the red bars peaking in these ranges.
#
# **2️⃣ Younger Employees Are More Affected:**
#
# The number of employees needing treatment (red) is consistently higher than those not needing treatment (green) in the 23–38 age group, indicating younger employees might be more vulnerable.
#
# **3️⃣ Decline in Treatment Need With Age:**
#
# As age increases beyond 38 years, both groups decline, but the number of people not needing treatment (green bars) remains relatively stable, suggesting older employees might have better coping mechanisms or lower stress levels.

# %%
plt.figure(figsize=(8, 5))  
# Creates a figure with a size of 8 inches wide and 5 inches tall.

# Countplot for gender and treatment
sns.countplot(data=df, x="Gender", hue="treatment", palette={"Yes": "red", "No": "green"})  
# Creates a count plot showing the number of employees by gender.
# 'x="Gender"' means gender categories will be on the x-axis.
# 'hue="treatment"' separates the bars based on treatment requirement (Yes/No).
# 'palette={"Yes": "red", "No": "green"}' assigns colors: red for "Yes" and green for "No".

plt.title("Treatment Requirement by Gender")  
# Sets the title of the plot.

plt.xlabel("Gender")  
# Labels the x-axis as "Gender".

plt.ylabel("Count")  
# Labels the y-axis as "Count" (number of employees in each gender category).

plt.legend(title="Needs Treatment")  
# Adds a legend with the title "Needs Treatment" to differentiate Yes/No categories.

plt.xticks(rotation=45)  
# Rotates x-axis labels by 45 degrees for better readability (useful if there are long labels).

plt.show()  
# Displays the plot.

# %% [markdown]
# **1️⃣ Males have a higher total count compared to females in the dataset, as their bars are significantly taller.**
#
# **2️⃣ More males do not need treatment (green bar) compared to those who do (red bar), suggesting a lower overall proportion of treatment need among males.**
#
# **3️⃣ Among females, the proportion needing treatment (red) is much higher compared to those who do not (green).**
#
# This suggests that females in the dataset are more likely to require mental health treatment compared to males.

# %%
grouped = df.groupby(["Gender", "family_history", "treatment"]).size().unstack()  
# Groups the data by "Gender", "family_history", and "treatment".
# Counts the number of occurrences for each group.
# 'unstack()' reshapes the data so that "treatment" categories become separate columns.

# Stacked bar chart
grouped.plot(kind="bar", stacked=True, figsize=(10, 6), color=["green", "red"])  
# Plots a stacked bar chart.
# 'kind="bar"' creates a bar chart.
# 'stacked=True' stacks bars to show proportions within each group.
# 'figsize=(10,6)' sets the figure size.
# 'color=["green", "red"]' assigns green to "Does Not Need Treatment" and red to "Needs Treatment".

plt.title("Impact of Family History on Treatment Need by Gender")  
# Sets the title of the plot.

plt.xlabel("Gender & Family History")  
# Labels the x-axis to indicate the combination of Gender and Family History.

plt.ylabel("Count")  
# Labels the y-axis as "Count" (number of employees in each category).

plt.legend(["Does Not Need Treatment", "Needs Treatment"], title="Treatment")  
# Adds a legend to differentiate between employees who need treatment (red) vs. those who don’t (green).

plt.show()  
# Displays the plot.

# %% [markdown]
# **1️⃣ Males Without Family History (Male, No)**
#
# Majority of this group does not need treatment (green bar is significantly higher).
# However, a notable portion still requires treatment (red bar).
#
# **2️⃣ Males With Family History (Male, Yes)**
#
# A significant number of males with a family history of mental illness need treatment (red bar is larger compared to "Male, No").
# This suggests that family history plays a role in mental health treatment needs for males.
#
# **3️⃣ Females Without Family History (Female, No)**
#
# The number of females without a family history needing treatment is relatively low compared to males.
# Most in this group do not require treatment.
#
# **4️⃣ Females With Family History (Female, Yes)**
#
# The number of females needing treatment increases when there is a family history.
# However, the increase is not as drastic as in males.

# %%
plt.figure(figsize=(12, 5))  
# Creates a figure with a size of 12 inches wide and 5 inches tall.

# First pie chart - Willingness to discuss mental health with coworkers
plt.subplot(1, 2, 1)  
# Creates a subplot in a 1-row, 2-column layout and selects the first plot.

df['coworkers'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['skyblue', 'salmon', 'lightgreen'])  
# Creates a pie chart showing the proportion of employees willing to discuss mental health with coworkers.
# 'value_counts()' counts the occurrences of each category.
# 'kind="pie"' specifies a pie chart.
# 'autopct='%1.1f%%'' displays percentage values on the chart.
# 'colors=['skyblue', 'salmon', 'lightgreen']' sets custom colors for each category.

plt.title("Willingness to Discuss Mental Health with Coworkers")  
# Sets the title for the first pie chart.

plt.ylabel('')  
# Hides the default y-axis label for a cleaner look.

# Second pie chart - Willingness to discuss mental health with supervisors
plt.subplot(1, 2, 2)  
# Creates a second subplot in the same 1-row, 2-column layout.

df['supervisor'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightcoral', 'lightblue', 'yellowgreen'])  
# Creates a pie chart showing the proportion of employees willing to discuss mental health with supervisors.
# Uses different colors: 'lightcoral', 'lightblue', 'yellowgreen'.

plt.title("Willingness to Discuss Mental Health with Supervisors")  
# Sets the title for the second pie chart.

plt.ylabel('')  
# Hides the default y-axis label.

plt.tight_layout()  
# Adjusts the layout to prevent overlapping of elements.

plt.show()  
# Displays the two pie charts.

# %% [markdown]
# **1️⃣ Willingness to Discuss Mental Health with Coworkers:**
#
# + A majority (62.1%) of employees are comfortable discussing mental health issues with some of their coworkers.
# + Only 17.9% are fully open to discussing it with coworkers.
# + 20% of employees are not willing to discuss mental health with their coworkers.
#
# **2️⃣ Willingness to Discuss Mental Health with Supervisors:**
#
# + 42.2% of employees are open to discussing mental health with their supervisors.
# + 27.1% prefer discussing it with only some supervisors.
# + 30.7% of employees are not comfortable discussing mental health with their supervisors.
#
# Employees are more hesitant to openly discuss mental health with supervisors compared to coworkers.
#
# The category "Some of them" is dominant in both cases, indicating that employees selectively choose who they confide in.
#
# A significant portion of employees (30.7% with supervisors & 20% with coworkers) still avoid discussing mental health at work.

# %%
plt.figure(figsize=(10, 6))  
# Creates a figure with a size of 10 inches wide and 6 inches tall.

sns.countplot(data=df, x="Gender", hue="coworkers", palette="Set2")  
# Creates a count plot to show how many employees in each gender category are willing to discuss mental health with coworkers.
# 'x="Gender"' places gender categories on the x-axis.
# 'hue="coworkers"' colors the bars based on responses about discussing mental health with coworkers.
# 'palette="Set2"' applies a visually distinct color scheme for clarity.

plt.title("Willingness to Discuss Mental Health with Coworkers by Gender")  
# Sets the title of the plot.

plt.xlabel("Gender")  
# Labels the x-axis as "Gender".

plt.ylabel("Count")  
# Labels the y-axis as "Count" (number of employees in each gender category).

plt.legend(title="Would Discuss with Coworkers")  
# Adds a legend to differentiate the categories of willingness to discuss mental health with coworkers.

plt.show()  
# Displays the plot.

# %% [markdown]
# **1️⃣ Majority prefer selective discussions**
#
# + Most employees, regardless of gender, prefer discussing mental health issues with only some coworkers rather than openly with everyone.
# + This suggests caution or hesitancy in openly discussing mental health at work.
#
# **2️⃣ Gender differences in openness**
#
# + Males show significantly higher participation across all categories, likely due to a higher proportion in the dataset.
# + However, within males, a substantial portion is comfortable discussing mental health openly ("Yes") compared to females.
#
# **3️⃣ Females show lower willingness overall**
#
# + Fewer females openly discuss mental health with coworkers.
# + A higher proportion of females say "No" to discussing mental health at work compared to males.
#
# **4️⃣ Stigma or workplace culture influence**
#
# + The significant number of people choosing "Some of them" suggests workplace culture and stigma may impact openness about mental health.
# + Organizations should focus on creating a more open and supportive environment to reduce hesitation.

# %%
df_subset = df[['mental_health_consequence', 'coworkers', 'supervisor']]  
# Creates a subset of the dataframe containing only the relevant columns:
# - "mental_health_consequence" (perceived negative consequences of discussing mental health at work)
# - "coworkers" (willingness to discuss mental health with coworkers)
# - "supervisor" (willingness to discuss mental health with supervisors)

# Counting occurrences
df_counts = df_subset.groupby(['mental_health_consequence', 'coworkers']).size().unstack()  
# Groups data by "mental_health_consequence" and "coworkers".
# Counts the number of occurrences for each combination.
# 'unstack()' reshapes the data so that "coworkers" responses become separate columns.

# Plotting
df_counts.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='viridis')  
# Creates a stacked bar chart to compare willingness to discuss mental health with coworkers.
# 'kind="bar"' creates a bar chart.
# 'stacked=True' stacks bars to show proportions within each category.
# 'figsize=(10,6)' sets the figure size.
# 'colormap="viridis"' applies a visually appealing color gradient.

plt.title("Mental Health Consequences vs Willingness to Discuss with Coworkers")  
# Sets the title of the plot.

plt.xlabel("Perceived Negative Consequences")  
# Labels the x-axis as "Perceived Negative Consequences".

plt.ylabel("Number of Employees")  
# Labels the y-axis as "Number of Employees".

plt.legend(title="Willing to Discuss with Coworkers")  
# Adds a legend to indicate different categories of willingness to discuss.

plt.xticks(rotation=45)  
# Rotates x-axis labels by 45 degrees for better readability.

plt.show()  
# Displays the plot.

# %% [markdown]
# **1️⃣ Employees who believe there are no negative consequences ("No")**
#
# + More employees in this category are willing to discuss mental health with coworkers.
# + The "Yes" and "Some of them" segments dominate this group, indicating a positive workplace culture.
#
# **2️⃣ Employees who are uncertain about negative consequences ("Maybe")**
#
# + A significant portion of employees still discuss mental health with coworkers.
# + However, the "No" responses are slightly higher than in the "No consequences" group, showing some hesitation due to uncertainty.
#
# **3️⃣ Employees who fear negative consequences ("Yes")**
#
# + The majority of this group is reluctant to discuss mental health with coworkers.
# + The "No" responses are the highest, showing that fear of negative consequences discourages open discussions.
#
# Workplace perception of negative consequences directly influences openness about mental health.
#
# Organizations that create a supportive environment can increase willingness to discuss mental health, improving overall employee well-being.
#
# More awareness and policies are needed to reassure employees that discussing mental health will not lead to negative consequences.

# %%
plt.figure(figsize=(14, 6))  
# Creates a figure with a size of 14 inches wide and 6 inches tall.

# First pie chart - Perceived consequences of discussing mental health
plt.subplot(1, 2, 1)  
# Creates a subplot in a 1-row, 2-column layout and selects the first plot.

df['mental_health_consequence'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['skyblue', 'salmon', 'lightgreen'])  
# Creates a pie chart showing the distribution of responses regarding the perceived consequences of discussing mental health at work.
# 'value_counts()' counts the occurrences of each response.
# 'kind="pie"' specifies a pie chart.
# 'autopct='%1.1f%%'' displays percentage values on the chart.
# 'colors=['skyblue', 'salmon', 'lightgreen']' sets custom colors.

plt.title("Mental Health Consequences")  
# Sets the title for the first pie chart.

plt.ylabel('')  
# Hides the default y-axis label for a cleaner look.

# Second pie chart - Perceived consequences of discussing physical health
plt.subplot(1, 2, 2)  
# Creates a second subplot in the same 1-row, 2-column layout.

df['phys_health_consequence'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightcoral', 'lightblue', 'yellowgreen'])  
# Creates a pie chart showing the distribution of responses regarding the perceived consequences of discussing physical health at work.
# Uses different colors: 'lightcoral', 'lightblue', 'yellowgreen'.

plt.title("Physical Health Consequences")  
# Sets the title for the second pie chart.

plt.ylabel('')  
# Hides the default y-axis label.

plt.tight_layout()  
# Adjusts the layout to prevent overlapping of elements.

plt.show()  
# Displays the two pie charts.

# %% [markdown]
# **1️⃣ Mental Health Consequences**
#
# + 40.8% of employees believe there are no mental health consequences at work.
# + 36.5% think there might be consequences.
# + 22.6% feel that discussing mental health will definitely have consequences.
#
# 📌 A significant portion of employees are either uncertain or believe there are consequences, which may discourage open discussions about mental health in the workplace.
#
# **2️⃣ Physical Health Consequences**
#
# + 74.1% of employees believe there are no physical health consequences.
# + 21.5% think there might be consequences.
# + Only 4.4% believe there are definite consequences.
#
# 📌 Employees are far less concerned about physical health-related consequences than mental health-related ones. This suggests that workplace stigma is stronger for mental health issues than physical health concerns.
#
# + The workplace appears to be more accepting of physical health issues than mental health concerns.
#
# + Uncertainty ("Maybe") is higher for mental health than physical health, indicating a lack of clarity or fear regarding potential consequences.
#
# * Companies should focus on reducing mental health stigma and encouraging open discussions to foster a supportive work environment.

# %%
plt.figure(figsize=(12, 6))  
# Creates a figure with a size of 12 inches wide and 6 inches tall.

# Countplot for physical health interview
plt.subplot(1, 2, 1)  
# Creates a subplot in a 1-row, 2-column layout and selects the first plot.

sns.countplot(data=df, x="phys_health_interview", palette="Set2")  
# Creates a count plot showing the number of employees willing to discuss physical health issues in an interview.
# 'data=df' specifies the dataset.
# 'x="phys_health_interview"' places the responses on the x-axis.
# 'palette="Set2"' applies a visually distinct color scheme.

plt.title("Physical Health Interview")  
# Sets the title for the first plot.

plt.xlabel("Response")  
# Labels the x-axis as "Response".

plt.ylabel("Count")  
# Labels the y-axis as "Count".

plt.xticks(rotation=45)  
# Rotates x-axis labels by 45 degrees for better readability.

# Countplot for mental health interview
plt.subplot(1, 2, 2)  
# Creates a second subplot in the same 1-row, 2-column layout.

sns.countplot(data=df, x="mental_health_interview", palette="Set2")  
# Creates a count plot showing the number of employees willing to discuss mental health issues in an interview.
# Uses the same color scheme for consistency.

plt.title("Mental Health Interview")  
# Sets the title for the second plot.

plt.xlabel("Response")  
# Labels the x-axis as "Response".

plt.ylabel("Count")  
# Labels the y-axis as "Count".

plt.tight_layout()  
# Adjusts the layout to prevent overlapping of elements.

plt.show()  
# Displays the two bar charts.
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_1276\597491737.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="phys_health_interview", palette="Set2")
# C:\Users\prath\AppData\Local\Temp\ipykernel_1276\597491737.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="mental_health_interview", palette="Set2")

# %% [markdown]
# **1️⃣ Physical Health Interview:**
#
# + The majority of employees selected "Maybe", suggesting uncertainty about discussing physical health issues in an interview.
# + A significant number responded with "No", indicating they would avoid bringing up physical health conditions.
# + Only a small group chose "Yes", meaning very few employees are comfortable discussing physical health with potential employers.
#
# 📌 Employees are hesitant to discuss physical health conditions in interviews, with many unsure about whether it's appropriate.
#
# **2️⃣ Mental Health Interview:**
#
# + A vast majority responded "No", meaning they would not disclose a mental health condition in an interview.
# + A much smaller portion chose "Maybe", showing some uncertainty.
# + Very few employees selected "Yes", indicating that discussing mental health openly in an interview is rare.
#
# 📌 The reluctance to disclose mental health issues is even stronger compared to physical health. This could stem from stigma or fear of negative impact on hiring decisions.
#
# **Key Takeaways:**
#
# + Employees are more hesitant to discuss mental health than physical health in job interviews.
# + Stigma and fear of discrimination may discourage open conversations about health issues in professional settings.
# + Workplace policies that encourage transparency and support could help create a safer environment for employees to discuss their health without fear.

# %%
columns_to_encode = ['mental_vs_physical', 'work_interfere', 'benefits', 'care_options', 'wellness_program', 'seek_help']  
# Selects categorical columns that represent employer policies and employee experiences regarding mental vs. physical health.

df_encoded = df[columns_to_encode].apply(lambda x: pd.factorize(x)[0])  
# Converts categorical variables into numerical format.
# 'pd.factorize(x)' assigns unique integer values to each category, making them suitable for correlation analysis.

# Compute correlation matrix
corr_matrix = df_encoded.corr()  
# Calculates the correlation matrix, which measures how strongly different variables are related to each other.

# Plot heatmap
plt.figure(figsize=(10,6))  
# Sets the figure size to 10x6 inches.

sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)  
# Creates a heatmap to visualize the correlation between employer-provided mental health policies and other workplace factors.
# 'annot=True' displays correlation values inside the heatmap cells.
# 'cmap="coolwarm"' uses a color gradient to show positive (red) and negative (blue) correlations.
# 'fmt=".2f"' ensures values are displayed with two decimal places.
# 'linewidths=0.5' adds thin grid lines for better readability.

plt.title("Correlation Heatmap: Employer's Mental vs. Physical Health Approach")  
# Sets the title of the heatmap.

plt.show()  
# Displays the heatmap.
columns_to_encode = ['mental_vs_physical', 'work_interfere', 'benefits', 'care_options', 'wellness_program', 'seek_help']
df_encoded = df[columns_to_encode].apply(lambda x: pd.factorize(x)[0])

# Compute correlation matrix
corr_matrix = df_encoded.corr()

# Plot heatmap
plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap: Employer's Mental vs. Physical Health Approach")
plt.show()

# %% [markdown]
# **1️⃣ Mental vs. Physical Health Perception (mental_vs_physical)**
#
# + Positively correlated with seek_help (0.25) → Employees who feel their employer values mental health as much as physical health are more likely to acknowledge the availability of mental health resources.
# + Negatively correlated with wellness_program (-0.24) → This suggests that simply discussing mental health in wellness programs does not strongly influence employees' perception of mental health parity.
#
# **2️⃣ Mental Health Benefits (benefits)**
#
# + Positively correlated with seek_help (0.52) → Companies offering mental health benefits have employees who actively seek help and utilize resources.
# + Negatively correlated with wellness_program (-0.43) → This suggests that formal wellness programs alone may not be sufficient, and direct benefits (like therapy coverage) are more impactful.
#
# **3️⃣ Awareness of Mental Health Care Options (care_options)**
#
# + Weak correlation with mental_vs_physical (-0.02) → Just knowing about mental health care options does not necessarily impact employees’ perception of how seriously mental health is taken.
# + Weak negative correlation with benefits (-0.09) → Awareness of care options does not always align with actually having strong mental health benefits.
#
# **4️⃣ Wellness Programs (wellness_program)**
#
# + Negatively correlated with seek_help (-0.62) → A strong inverse relationship suggests that employees in companies with wellness programs may not find them useful for seeking mental health help.
# + Negative correlation with benefits (-0.43) → Suggests that wellness programs alone do not replace tangible mental health benefits.
#
# **5️⃣ Seeking Help (seek_help)**
#
# + Strong correlation with benefits (0.52) → Companies that provide mental health benefits directly impact employees’ willingness to seek help.
# + Strong negative correlation with wellness_program (-0.62) → Suggests that wellness discussions alone are insufficient; direct benefits and care options matter more.

# %%
plt.figure(figsize=(8, 6))  
# Sets the figure size to 8 inches wide and 6 inches tall.

df['care_options'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['skyblue', 'salmon', 'lightgreen'])  
# Creates a pie chart showing the distribution of responses regarding awareness of mental health care options.
# 'value_counts()' counts how many times each response appears.
# 'kind="pie"' specifies a pie chart.
# 'autopct='%1.1f%%'' displays percentage values on the chart.
# 'colors=['skyblue', 'salmon', 'lightgreen']' assigns specific colors to the slices.

plt.title("Awareness of Mental Health Care Options")  
# Sets the title of the pie chart.

plt.ylabel('')  
# Hides the default y-axis label for a cleaner look.

plt.show()  
# Displays the pie chart.

# %% [markdown]
# **1️⃣ Low Awareness (40.6%)**
#
# + A significant portion of employees (40.6%) are unaware of the mental health care options available to them.
# + This suggests a need for better communication and visibility of mental health support programs within the organization.
#
# **2️⃣ Moderate Awareness (25.1%)**
#
# + 25.1% of employees are unsure about the available mental health care options.
# + This uncertainty may indicate a lack of clarity in company policies or insufficient awareness campaigns.
#
# **3️⃣ High Awareness (34.3%)**
#
# + Only 34.3% of employees are aware of the mental health care options provided by their employer.
# + While this is a positive sign, it highlights the need for further efforts to increase awareness and ensure all employees know how to access support.

# %%
plt.figure(figsize=(12, 6))  
# Creates a figure with a size of 12 inches wide and 6 inches tall.

# Countplot for anonymity vs mental health interview
sns.countplot(data=df, x="anonymity", hue="mental_health_interview", palette="Set2")  
# Creates a count plot showing the number of employees based on their anonymity and willingness to discuss mental health in an interview.
# 'x="anonymity"' places the anonymity categories on the x-axis.
# 'hue="mental_health_interview"' colors the bars based on responses about discussing mental health in an interview.
# 'palette="Set2"' applies a visually distinct color scheme for clarity.

plt.title("Anonymity vs Willingness to Discuss Mental Health in Interview")  
# Sets the title of the plot.

plt.xlabel("Anonymity")  
# Labels the x-axis as "Anonymity".

plt.ylabel("Count")  
# Labels the y-axis as "Count" (number of employees in each category).

plt.legend(title="Mental Health Interview")  
# Adds a legend to differentiate the categories of willingness to discuss mental health in an interview.

plt.xticks(rotation=45)  
# Rotates x-axis labels by 45 degrees for better readability.

plt.show()  
# Displays the plot.

# %% [markdown]
# **1️⃣ Majority are unaware of anonymity policies**
#
# + The highest count is for employees who answered "Don't know" regarding anonymity.
# + This indicates a lack of clarity in company policies about anonymity protections.
#
# **2️⃣ Employees who are unsure about anonymity are less likely to discuss mental health**
#
# + Most employees in the "Don't know" category chose "No" for discussing mental health in interviews.
# + This suggests that uncertainty about anonymity discourages open discussions.
#
# **3️⃣ Employees with anonymity protection are slightly more open to discussing**
#
# + Those who answered "Yes" to anonymity have a relatively higher proportion of "Maybe" or "Yes" responses compared to the other groups.
# + This indicates that anonymity positively influences willingness to discuss mental health.
#
# **4️⃣ Employees without anonymity protection are the least likely to discuss**
#
# + The "No" category has very few people selecting "Maybe" or "Yes".
# + This implies that a lack of anonymity is a significant barrier to open discussions about mental health in interviews.

# %% [markdown]
# # Key Analysis
# **1️⃣ Mental Health Concerns Are Prevalent in the Workplace**
#
# + Nearly 48.2% of employees indicated they needed treatment, showing that mental health issues are a significant workplace concern.
#
# **2️⃣ Younger Employees (23-38) Are More Affected**
#
# + Employees aged 23-28 and 33-38 show the highest need for mental health treatment, highlighting potential stressors at different career stages.
#
# **3️⃣ Older Employees Show Lower Treatment Needs**
#
# + Beyond 38 years, treatment needs decline, suggesting better coping mechanisms or lower workplace stress for older employees.
#
# **4️⃣ Gender Differences Exist in Mental Health Treatment**
#
# + Females have a higher proportion needing treatment compared to males, suggesting gender-based workplace stressors or differences in mental health awareness.
#
# **5️⃣ Family History Increases the Need for Treatment**
#
# + Employees with a family history of mental illness are significantly more likely to require mental health treatment, especially males.
#
# **6️⃣ Employees Are Selective About Discussing Mental Health**
#
# + Most employees prefer discussing mental health only with some coworkers or supervisors, indicating hesitation and fear of judgment.
#
# **7️⃣ Fear of Negative Consequences Reduces Openness**
#
# + Employees who fear workplace repercussions are far less likely to discuss mental health, while those who believe there are no consequences are more open.
#
# **8️⃣ Mental Health Is Stigmatized More Than Physical Health**
#
# + 74.1% believe physical health disclosures have no consequences, while only 40.8% feel the same about mental health, showing a stigma gap.
#
# **9️⃣ Employees Hesitate to Discuss Health in Job Interviews**
#
# + More employees avoid discussing mental health than physical health in job interviews, fearing discrimination in hiring decisions.
#
# **🔟 Workplace Wellness Programs Alone Are Not Effective**
#
# + Negative correlation (-0.62) between wellness programs and seeking help suggests that companies need to offer direct mental health benefits rather than just awareness initiatives.
#
# **1️⃣1️⃣ Mental Health Benefits Encourage Employees to Seek Help**
#
# + Employees in companies with mental health benefits are far more likely to seek help, showing that financial and organizational support matters.
#
# **1️⃣2️⃣ Awareness of Mental Health Care Options Is Low**
#
# + 40.6% of employees are unaware of their employer’s mental health support, indicating poor communication and the need for better outreach.
#
# **1️⃣3️⃣ Perception of Employer Support Affects Mental Health Actions**
#
# + Employees who believe their employer values mental health as much as physical health are more likely to use available mental health resources.
#
# **1️⃣4️⃣ Anonymity Policies Impact Openness**
#
# + Employees unsure about anonymity protections are less likely to discuss mental health, while those who believe anonymity is ensured are more open.
#
# **1️⃣5️⃣ Companies Must Prioritize Mental Health Awareness and Support**
#
# + Reducing stigma, increasing transparency, and ensuring proper benefits and policies can encourage employees to seek help and improve overall workplace well-being.

# %% [markdown]
# # Prescription
#
# **1️⃣ Increase Awareness of Mental Health Resources**
#
# 📌 Insight: 40.6% of employees are unaware of available mental health care options.
#
# ✅ Action:
# - Conduct regular awareness campaigns about mental health resources.
# - Make mental health support information easily accessible through emails, posters, and the company portal.
#
# **2️⃣ Ensure Anonymity in Mental Health Discussions**
#
# 📌 Insight: Employees unsure about anonymity are hesitant to discuss mental health.
#
# ✅ Action:
# - Implement clear anonymity policies for mental health discussions and ensure employees are informed.
# - Provide anonymous mental health support channels such as helplines or chat-based counseling.
#
# **3️⃣ Normalize Conversations About Mental Health**
#
# 📌 Insight: 62.1% of employees are comfortable discussing mental health with some coworkers, but only 17.9% are fully open.
#
# ✅ Action:
# - Train managers and team leads on how to foster open conversations about mental well-being.
# - Create mental health peer-support groups to encourage safe discussions.
#
# **4️⃣ Address Stigma in the Workplace**
#
# 📌 Insight: 22.6% of employees believe discussing mental health has negative consequences.
#
# ✅ Action:
# - Introduce strict anti-discrimination policies related to mental health.
# - Conduct leadership workshops to reinforce that mental health concerns should be treated like physical health issues.
#
# **5️⃣ Enhance Mental Health Benefits & Wellness Programs**
#
# 📌 Insight: Companies offering mental health benefits have employees more likely to seek help.
#
# ✅ Action:
# - Provide coverage for therapy and mental health consultations.
# - Revamp wellness programs to include stress management, mindfulness sessions, and resilience-building workshops.
#
# **6️⃣ Encourage Employees to Seek Help**
#
# 📌 Insight: The correlation between wellness programs and employees seeking help is negative (-0.62), meaning awareness alone isn't enough.
#
# ✅ Action:
# - Actively promote Employee Assistance Programs (EAPs) and ensure easy access to counseling services.
# - Offer incentives for participating in mental health programs (e.g., wellness reimbursements, mental health days).
#
# **7️⃣ Foster a Supportive Leadership Culture**
#
# 📌 Insight: Employees are more hesitant to discuss mental health with supervisors than coworkers.
#
# ✅ Action:
# - Train managers on how to handle mental health discussions with empathy and discretion.
# - Encourage leaders to share their own experiences with mental well-being, fostering a culture of openness.
#
# **8️⃣ Clarify Workplace Consequences of Discussing Mental Health**
#
# 📌 Insight: Uncertainty about negative consequences impacts employees’ willingness to discuss mental health.
#
# ✅ Action:
# - Clearly communicate that seeking mental health support will not impact career progression.
# - Include mental health policies in employee handbooks and orientation programs.
#
# **9️⃣ Tailor Wellness Programs to Different Age Groups**
#
# 📌 Insight: Younger employees (ages 23–38) show a higher need for mental health support.
#
# ✅ Action:
# - Offer targeted programs addressing stress management, work-life balance, and burnout prevention for younger employees.
# - Provide mentorship programs for younger employees to navigate workplace challenges.
#
# **🔟 Strengthen Mental Health Education in Recruitment**
#
# 📌 Insight: Employees are hesitant to discuss mental health in interviews due to fear of bias.
#
# ✅ Action:
# - Train HR personnel to foster a stigma-free hiring process.
# - Communicate that mental health conditions will not be used to discriminate against candidates.
